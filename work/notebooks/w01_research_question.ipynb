# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MuhammadOmerSiddiqui/myInternship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# I choose **Lane 2: Refresh / Content Opportunity Scoring**.
#
# I want to rank which existing pages should be reviewed first for a possible refresh, expansion, or monitoring. The starter dataset already has trend direction, content age, impressions, position, CTR, and engagement signals, so this lane can be started immediately and is realistic for the next 7 weeks. The decision is practical: editors have limited time and need a prioritized queue instead of looking at pages randomly.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# **Decision this improves:** Which pages should a content editor or SEO specialist review first this week?
#
# **Who acts and what do they do:** A human editor opens the top pages from a ranked list, checks the page, and decides whether to refresh the content, expand it, improve the title/meta, or just monitor it.
#
# **Cost of a wrong recommendation:**
# - Ranking a low-value page high wastes limited editor hours.
# - Ranking a high-value declining page low means the team may miss an opportunity and the page keeps losing visibility.
#
# This is decision-support, not automatic publishing. Data and ML help because many signals (age, trend, impressions, position, CTR, engagement) interact in ways that are hard to write as a single fixed rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# From the starter dataset (`content_refresh_anonymized.csv`):
#
# - There are **30,000** pages.
# - **16,262** pages (54.2%) are already labeled as declining (`trend_direction == "down"`).
# - **9,929** pages are both older than 180 days **and** still receive at least 500 impressions in the last 90 days.
#
# These numbers show there is a large pool of pages that combine demand (impressions) with possible risk (age + declining trend). Ranking them so the highest-priority ones are reviewed first is therefore worth the next 7 weeks of work.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os
import sys
import subprocess
import pandas as pd

IN_COLAB = "google.colab" in sys.modules

if IN_COLAB:
    REPO = "myInternship"
    if not os.path.isdir(REPO):
        subprocess.run(
            ["git", "clone", "--depth", "1",
             "https://github.com/MuhammadOmerSiddiqui/myInternship.git", REPO],
            check=True
        )
    os.chdir(REPO)
    print("Working directory set to:", os.getcwd())

csv_path = "data/raw/content_refresh_anonymized.csv"
assert os.path.exists(csv_path), f"Still cannot find {csv_path}. Current dir: {os.getcwd()}"

df = pd.read_csv(csv_path)

print("Total pages:", len(df))
print("Declining pages:", (df["trend_direction"] == "down").sum())
print("Declining rate: {:.1%}".format((df["trend_direction"] == "down").mean()))
print("Pages older than 180 days AND impressions >= 500:",
      ((df["content_age_days"] >= 180) & (df["impressions_90d"] >= 500)).sum())
# Out:
# Working directory set to: /content/myInternship/myInternship/myInternship
# Total pages: 30000
# Declining pages: 16262
# Declining rate: 54.2%
# Pages older than 180 days AND impressions >= 500: 9929

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# **What I can claim**
# - Observed patterns in the data (e.g. many older pages still receive impressions and are declining).
# - A ranked list that can serve as **decision-support** for a human reviewer.
# - Directional results: “these pages look higher priority based on the signals we measured.”
#
# **What I cannot claim**
# - That refreshing a page will cause traffic to recover (we have no experiment that proves causation).
# - That I predicted Google’s ranking algorithm.
# - That the model is production-ready without human review.
# - Any result based on private client names, real URLs, or raw keywords (none of those exist in this dataset).
#
# All claims will stay observational, measured, and decision-support only.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
