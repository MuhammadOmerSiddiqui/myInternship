# %% [markdown]
# # Capstone — mirrors your deployed research paper
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MuhammadOmerSiddiqui/myInternship/blob/main/work/notebooks/capstone.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Question
#
# *The research question and the decision it supports.*

# %% [markdown]
# ## 2. Data
#
# *Which release, which tables, date windows, what you excluded and why. Public-safe.*

# %% [markdown]
# ## 3. Methodology
#
# *Assumptions, features, label definition, baseline, validation design, leakage checks.*

# %% [markdown]
# ## 4. Results (vs baseline)
#
# *Model vs baseline on the same split. The honest table.*

# %% [markdown]
# ## 5. Limitations
#
# *What this work cannot claim.*

# %% [markdown]
# ## 6. Ranked recommendations
#
# *The action playbook output — the paper's recommendations section.*

# %% [markdown]
# ## 7. Artifacts the paper embeds
#
# *Generate/collect the charts and tables your deployed page will show.*

# %% [markdown]
# ## Week 8 — Tell the Story
#
# ### 5-minute demo outline
#
# 1. **Question (30s)**
#    Which pages should an editor review first for refresh or CTR work?
#
# 2. **Method (60s)**
#    Starter dataset (30k pages) · declining proxy label · honest features · baseline rule · Random Forest · client-holdout validation · leakage audit.
#
# 3. **One chart (60s)**
#    Model vs baseline Precision@50 on the same client-holdout split.
#
# 4. **One honest result (60s)**
#    Learned ranking beats the fixed rule on Precision@50; random splits look better than client-holdout — we keep the honest number.
#
# 5. **One recommendation (60s)**
#    Use the ranked playbook with reason codes; human review required; do not auto-publish.
#
# ---
#
# ### Social post (shareable as-is)
#
# Built a content refresh-priority ranker on 30k anonymized search pages from the FlyRank ML Internship dataset. A transparent baseline rule vs Logistic Regression / Tree / Forest under client-holdout validation — the model improves Precision@50. Output is a ranked review queue with reason codes for editors. Decision-support only, not causal SEO magic.
#
# Repo: https://github.com/MuhammadOmerSiddiqui/myInternship
#
# ---
#
# ### Employer-facing summary (3 sentences)
#
# I framed a content-refresh prioritization problem for search-driven pages and built a ranked action playbook on the FlyRank ML Internship anonymized dataset (30,000 pages, 32 clients). I compared a transparent hand-written baseline with Logistic Regression, Decision Tree, and Random Forest under a client-holdout split, with an explicit leakage audit. The best model improved Precision@50 over the rule and produces decision-support recommendations with reason codes for human editors — not automatic publishing.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
# - [ ] My deployed paper has **all 9 sections** — including the **Abstract** at the top and **Acknowledgments & data credit** (the https://flyrank.ai link) at the bottom.
# - [ ] **ML-12 done in this notebook's closing cells:** 5-minute demo outline + a social-post cut + a 3-sentence employer-facing summary.
